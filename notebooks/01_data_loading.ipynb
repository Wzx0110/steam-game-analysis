# %%
import pandas as pd
import os

# 設定檔案路徑
raw_data_path = '../data/raw/steam_app_data.csv' 

# 讀取數據
try:
    df = pd.read_csv(raw_data_path)
    print(f"資料大小: {df.shape}")
except FileNotFoundError:
    print("找不到檔案，請確認路徑與檔名是否正確。")

# 初步檢視
df.head()
# Out:
# 資料大小: (86538, 39)
# C:\Users\user\AppData\Local\Temp\ipykernel_20544\3763127752.py:9: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_info = pd.read_csv(raw_data_path)
#    type                       name  steam_appid  required_age is_free  \
# 0  game             Counter-Strike           10           0.0   False
# 1  game      Team Fortress Classic           20           0.0   False
# 2  game              Day of Defeat           30           0.0   False
# 3  game         Deathmatch Classic           40           0.0   False
# 4  game  Half-Life: Opposing Force           50           0.0   False
#
#   controller_support  dlc                               detailed_description  \
# 0                NaN  NaN  Play the world's number 1 online action game. ...
# 1                NaN  NaN  One of the most popular online action games of...
# 2                NaN  NaN  Enlist in an intense brand of Axis vs. Allied ...
# ...

# %%
# 讀取需要的兩份資料
df_metrics = pd.read_csv('../data/raw/all_data.csv')      # 成績單
df_info = pd.read_csv('../data/raw/steam_app_data.csv')   # 履歷表

# 檢查一下欄位名稱，確保都有 'steam_appid'
# 有時候 csv 的欄位名會有空白，先清除一下比較保險
df_metrics.columns = df_metrics.columns.str.strip()
df_info.columns = df_info.columns.str.strip()

print(f"合併前 - 成績單筆數: {df_metrics.shape[0]}")
print(f"合併前 - 履歷表筆數: {df_info.shape[0]}")

# 執行合併 (Merge)
# 使用 'inner' join，只保留兩邊都有資料的遊戲（確保資料完整性）
# 如果你想保留所有成績單上的遊戲，即便沒有詳細資訊，可以改用 'left'
df_merged = pd.merge(
    df_metrics, 
    df_info, 
    on='steam_appid', 
    how='inner', 
    suffixes=('_metrics', '_info') # 如果有重複欄位名，加上後綴區分
)

print(f"合併後 - 總資料筆數: {df_merged.shape}")

# 簡單檢查一下合併結果
df_merged.head(3)
# Out:
# 合併前 - 成績單(all_data)筆數: 86538
# 合併前 - 履歷表(steam_app_data)筆數: 86538
# 合併後 - 總資料筆數: (94509, 56)
#    Unnamed: 0  steam_appid                 name_x developer publisher  \
# 0           0           10         Counter-Strike     Valve     Valve
# 1           1           20  Team Fortress Classic     Valve     Valve
# 2           2           30          Day of Defeat     Valve     Valve
#
#    score_rank  positive  negative  userscore                    owners  ...  \
# 0         NaN    243818      6427          0  10,000,000 .. 20,000,000  ...
# 1         NaN      7602      1136          0    1,000,000 .. 2,000,000  ...
# 2         NaN      6414       688          0   5,000,000 .. 10,000,000  ...
#
#                                           categories  \
# 0  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 1  [{'id': 1, 'description': 'Multi-player'}, {'i...
# 2  [{'id': 1, 'description': 'Multi-player'}, {'i...
#
#                                    genres  \
# ...
